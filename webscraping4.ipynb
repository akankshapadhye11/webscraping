# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, ElementNotInteractableException
from selenium.webdriver.common.by import By
import time
import re

# %%
#connecting to the driver
driver=webdriver.Chrome(r"C:\python\chromedriver.exe")

# %% [markdown]
# # Q.1)

# %%
#opening url on automated browser
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
Rank=[]
Name=[]
Artist=[]
Views=[]
Upload_Date=[]

# %%
#Scrapping the details of the Rank of the video
rank=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[1]")
for i in rank[:30]:
    Rank.append(i.text)
    
#Scrapping the details of the video name
video=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[2]")
for i in video[:30]:
    Name.append(i.text)
    
#Scrapping the details of the Artist name
artist=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[3]")
for i in artist[:30]:
    Artist.append(i.text)
    
#Scrapping the details of the views information
views=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[4]")
for i in views[:30]:
    Views.append(i.text)
    
#Scrapping the details of the upload date
date=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[5]")
for i in date[:30]:
    Upload_Date.append(i.text)

# %%
#creating dataframe
df=pd.DataFrame({'Rank':Rank,'Name':Name,'Artist':Artist,'Uploaded-Date':Upload_Date,'Views':Views})
df
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                                  "Bath Song"[15]
# 5    6.                              "See You Again"[16]
# 6    7.                "Phonics Song with Two Words"[21]
# 7    8.                                "Uptown Funk"[22]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[23]
# 9   10.                              "Gangnam Style"[24]
# 10  11.   "Masha and the Bear – Recipe for Disaster"[29]
# 11  12.                          "Wheels on the Bus"[30]
# 12  13.                             "Dame Tu Cosita"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# ...

# %% [markdown]
# # Q.2)

# %%
#opening bcci website on automated browser
driver.get('https://www.bcci.tv/')

# %%
#reaching to international fixture page
fixture=driver.find_element(By.XPATH,'//a[@class="nav-link"]')
fixture.get_attribute('href')
fixture.click()
# Out:
# 'https://www.bcci.tv/#'

# %%
#creating an empty list
Match=[]
Series=[]
Place=[]
Date=[]
Time=[]

# %%
#Scrapping the data for match name
name=driver.find_elements(By.XPATH,"//span[@class='matchOrderText ng-binding ng-scope']")
for i in name:
    Match.append(i.text)

# %%
#Scrapping the data for series name
series=driver.find_elements(By.XPATH,"//div[@class='fixture-card-top']/h5[2]")
for i in series:
    Series.append(i.text)

# %%
#Scrapping the data for place
place=driver.find_elements(By.XPATH,"//span[@class='ng-binding ng-scope']")
for i in place:
    Place.append(i.text)

# %%
#Scrapping the data having the match date
date=driver.find_elements(By.XPATH,"//h5[@class='ng-binding']")
for i in date:
    Date.append(i.text)

# %%
#Scrapping the data for match time
time=driver.find_elements(By.XPATH,"//h5[@class='text-right ng-binding']")
for i in time:
    Time.append(i.text)

# %%
#creating dataframe
df=pd.DataFrame({'Match':Match,'Series':Series,'Place':Place,'Date':Date,'Time':Time})
df
# Out:
#         Match                                        Series  \
# 0  5th T20I -                   ICC MENS T20 WORLD CUP 2022
# 1  1st T20I -  INDIA TOUR OF NEW ZEALAND T20 SERIES 2022-23
# 2  2nd T20I -  INDIA TOUR OF NEW ZEALAND T20 SERIES 2022-23
# 3  3rd T20I -  INDIA TOUR OF NEW ZEALAND T20 SERIES 2022-23
# 4   1st ODI -  INDIA TOUR OF NEW ZEALAND ODI SERIES 2022-23
# 5   2nd ODI -  INDIA TOUR OF NEW ZEALAND ODI SERIES 2022-23
# 6   3rd ODI -  INDIA TOUR OF NEW ZEALAND ODI SERIES 2022-23
# 7   1st ODI -   INDIA TOUR OF BANGLADESH ODI SERIES 2022-23
#
#                                     Place         Date          Time
# 0               Melbourne Cricket Ground,   6 NOV 2022   1:30 PM IST
# 1                            Sky Stadium,  18 NOV 2022  12:00 PM IST
# 2                               Bay Oval,  20 NOV 2022  12:00 PM IST
# 3                            Mclean Park,  22 NOV 2022  12:00 PM IST
# 4                              Eden Park,  25 NOV 2022   7:00 AM IST
# ...

# %% [markdown]
# # Q.3)

# %%
#Getting the website on automated browser
driver.get('https://www.guru99.com/')

# %%
#reaching to selenium page
s=driver.find_element(By.XPATH,'//html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[2]/div[1]/div/ul[1]/li[3]/a')
s.get_attribute('href')
s.click()

# %%
#Clicking on the selenium exception tutorial page
se=driver.find_element(By.XPATH,"//html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a")
se.click()

# %%
#Creating the empty list to store the scraped data
Name=[]
#Scrapping the data having exception names and its description
name=driver.find_elements(By.XPATH,"//div[@class='entry-content single-content']/p")
for i in name:
    Name.append(i.text)

# %%
print(Name)
# Out:
# ['1. ElementNotVisibleException: This type of Selenium exception occurs when an existing element in DOM has a feature set as hidden.', '2. ElementNotSelectableException: This Selenium exception occurs when an element is presented in the DOM, but you can be able to select. Therefore, it is not possible to interact.', '3. NoSuchElementException: This Exception occurs if an element could not be found.', '4. NoSuchFrameException: This Exception occurs if the frame target to be switched to does not exist.', '5. NoAlertPresentException: This Exception occurs when you switch to no presented alert.', '6. NoSuchWindowException: This Exception occurs if the window target to be switch does not exist.', '7. StaleElementReferenceException: This Selenium exception occurs happens when the web element is detached from the current DOM.', '8. SessionNotFoundException: The WebDriver is acting after you quit the browser.', '9. TimeoutException: Thrown when there is not enough time for a command to be co
# ...

# %% [markdown]
# # Q.4)

# %%
#Getting the website to driver
driver.get('http://statisticstimes.com/')

# %%
#reaching to economy page
eco=driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]')
eco.get_attribute('href')
eco.click()

# %%
#reaching to india page
ind=driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]')
ind.get_attribute('href')
# Out:
# 'https://www.statisticstimes.com/economy/india-statistics.php'

# %%
Rank=[]
#Scrapping the data having rank of the states
rank=driver.find_elements(By.XPATH,"//td[@class='data1']")
for i in rank:
    if i.text is None :
        Rank.append("--") 
    else:
        Rank.append(i.text)

# %%
State=[]
#Scrapping the data having State name
state=driver.find_elements(By.XPATH,"//td[@class='name']")
for i in state:
    if i.text is None :
        State.append("--") 
    else:
        State.append(i.text)

# %%
GSDP19_20=[]
#Scrapping the data having GSDP 19-20 data
for i in driver.find_elements(By.XPATH,"//td[@class='data']"):
    GSDP19_20.append(i.text)

# %%
GSDP18_19=[]
#Scrapping the data having GSDP 18-19 data
for i in driver.find_elements(By.XPATH,"//td[@class='data sorting_1']"):
    GSDP18_19.append(i.text)

# %%
Share18_19=[]
#Scrapping the data having Share 18-19 data
for i in driver.find_elements(By.XPATH,"//td[@class='data']"):
    Share18_19.append(i.text)

# %%
GDP=[]
#Scrapping the data having GDP billions data
for i in driver.find_elements(By.XPATH,"//td[@class='data']"):
    GDP.append(i.text)

# %% [markdown]
# # Q.5)

# %%
#Getting the website to driver
driver.get('https://github.com/')

# %%
#Clicking explore tab
explore=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[2]/div/nav/ul/li[3]")
explore.click()

# %%
#Clicking trending option
trending=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/ul[3]/li[3]/a")
try:
    trending.click()
except ElementNotInteractableException as e:
    driver.get(trending.get_attribute('href'))

# %%
#scraping the Repositor_Name 
Repository_Name =[]
RN=driver.find_elements(By.XPATH,"//span[@class='text-normal']")
for i in RN:
    if i.text is None :
        Repository_Name.append("--") 
    else:
        Repository_Name.append(i.text)

# %%
#Scraping description
Description=[] 
des=driver.find_elements(By.XPATH,"//p[@class='col-9 color-fg-muted my-1 pr-4']")
for i in des:
    if i.text is None :
        Description.append("--") 
    else:
        Description.append(i.text)

# %%
#Scrapping the data having the contributors count
Count=[]
count=driver.find_elements(By.XPATH,"//a[@class='Link--muted d-inline-block mr-3']")
for i in count:
    Count.append(i.text)

# %%
#Scrapping the data having the language used
Language=[]
lang=driver.find_elements(By.XPATH,"//span[@itemprop='programmingLanguage']")
for i in lang:
    if i.text is None:
        Language.append('Not Available')
    else:
        Language.append(i.text)

# %%
#Creating a dataframe for the scrapped data
github=pd.DataFrame({})
github['Repository title']=Repository_Name[:21]
github['Description']=Description[:21]
github['Contributors count']=Count[:21]
github['Language used']=Language[:21]
github
# Out:
#             Repository title  \
# 0                  grafana /
# 1                  SheerSt /
# 2                refinedev /
# 3                   milanm /
# 4                  Netflix /
# 5               Taiga74164 /
# 6               karmada-io /
# 7                  labmlai /
# 8                 hellof2e /
# 9                   strapi /
# 10               lidangzzz /
# 11               microsoft /
# 12              pocketbase /
# 13              Olde-Skuul /
# 14               benphelps /
# 15                  poteto /
# 16               microsoft /
# 17  NationalSecurityAgency /
# 18                  apache /
# 19              prometheus /
# 20                  dotnet /
#
#                                           Description Contributors count  \
# 0   horizontally-scalable, highly-available, multi...                956
# 1        PokeWilds - A Gen 2 Game/Engine using libGDX                 21
# 2   Build your React-based CRUD applications, with...                793
# ...

# %% [markdown]
# # Q.6)

# %%
#Getting the website to driver
driver.get('https://www.billboard.com/')

# %%
#clicking on chart option
chart= driver.find_element(By.XPATH,'/html/body/div[3]/div[7]/div/div/div/ul/li[1]/h3/a')
chart.click()

# %%
#clicking on hot100 option
hot= driver.find_element(By.XPATH,'/html/body/div[3]/div[7]/div/div/div/ul/li[1]/ul/li[2]/a')
hot.click()

# %%
#Creating empty lists for storing the scrapped data
Song=[]
Artist=[]
Lastweek=[]
Peak=[]
Weeks_on_board=[]

# %%
#Scrapping the data having the song name
song=driver.find_elements(By.XPATH,"//h3[@class='c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only']")
for i in song:
    Song.append(i.text)

# %%
#Scrapping the data having the artist name
artist=driver.find_elements(By.XPATH,"//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only']")
for i in artist:
    Artist.append(i.text)

# %%
#Scrapping the data having the last week rank
last_week=driver.find_elements(By.XPATH,"//span[@class='c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max']")
for i in last_week:
    if i.text is None:
        Lastweek.append('-')
    else:
        Lastweek.append(i.text)

# %%
#Scrapping the data having the peak rank
peak=driver.find_elements(By.XPATH,"//span[@class='c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max']")
for i in peak:
    if i.text is None:
        Peak.append('-')
    else:
        Peak.append(i.text)

# %%
#Scrapping the data having weeks on board data
weeks=driver.find_elements(By.XPATH,"//span[@class='c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max']")
for i in weeks:
    if i.text is None:
        Weeks_on_board.append('-')
    else:
        Weeks_on_board.append(i.text)

# %%
#Creating a dataframe
df=pd.DataFrame({})
df['song']=Song[:99]
df['artist']=Artist
df['peak']=Peak[:99]
df['lastweek']=Lastweek[:99]
df['weeksonboard']=Weeks_on_board[:99]
df
# Out:
#                  song                               artist peak lastweek  \
# 0           Anti-Hero                         Taylor Swift    -        -
# 1       Lavender Haze                         Taylor Swift    2        2
# 2              Maroon  Taylor Swift Featuring Lana Del Rey    1        1
# 3   Snow On The Beach                         Taylor Swift
# 4       Midnight Rain                         Taylor Swift
# ..                ...                                  ...  ...      ...
# 94      Made You Look                           Steve Lacy
# 95           Dark Red            Lil Baby Featuring Future
# 96        From Now On                        Lewis Capaldi    6        6
# 97          Forget Me           Oliver Tree & Robin Schulz    6        6
# 98           Miss You                              Rosalia   20       20
#
#    weeksonboard
# 0             -
# 1             2
# 2             1
# 3
# 4
# ..          ...
# 94
# 95
# 96            6
# 97            6
# ...

# %% [markdown]
# # Q.7)

# %%
#Getting the website to driver
driver.get('https://www.naukri.com/hr-recruiters-consultants')

# %%
#Entering domain as required in question
d=driver.find_element(By.CLASS_NAME,'sugInp')
d.send_keys('Data Science')

# %%
search=driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/button")
search.click()

# %%
#Creating empty lists for storing the scrapped data
Name=[]
Designation=[]
Company=[]
Skills=[]
Location=[]

#Scrapping the data having the recruiter's name
name=driver.find_elements(By.XPATH,"//span[@class='fl ellipsis']")
for i in name:
    Name.append(i.text)
    
#Scrapping the data having the recruiter's designation
desc=driver.find_elements(By.XPATH,"//span[@class='ellipsis clr']")
for i in desc:
    Designation.append(i.text)
    
#Scrapping the data having company name
company=driver.find_elements(By.XPATH,"//p[@class='highlightable']/a[2]")
for i in company:
    Company.append(i.text)
    
#Scrapping the data having the skillset details
skills=driver.find_elements(By.XPATH,"//div[@class='hireSec highlightable']")
for i in skills:
    Skills.append(i.text)
    
#Scrapping the data having the location details
location=driver.find_elements(By.XPATH,"//small[@class='ellipsis']")
for i in location:
    Location.append(i.text)

# %%
#Creating a dataframe for the scrapped data
df=pd.DataFrame({})
df['Name']=Name[:48]
df['Designation']=Designation[:48]
df['Company']=Company[:48]
df['Skills']=Skills[:48]
df['Location']=Location
df
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                Kalpana Dumpala
# 11                                        Mubarak
# 12                                 Kushal Rastogi
# 13                             Mahesh Babu Channa
# 14                             Vaishnavi Kudalkar
# 15                                 Priyanka Akiri
# 16                                   Kapil Devang
# 17                                Sakshi Chhikara
# ...

# %% [markdown]
# # Q.8)

# %%
#Getting the website to driver
driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/')

# %%
#Creating empty lists to store the scrapped data
Book=[]
Author=[]
Volume=[]
Publisher=[]
Genre=[]

#Scrapping the data having the book name
book=driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[2]")
for i in book:
    Book.append(i.text)
    
#Scrapping the data having the author name
author=driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[3]")
for i in author:
    Author.append(i.text)
    
#Scrapping the data having the volumes sold details
volume=driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[4]")
for i in volume:
    Volume.append(i.text)

#Scrapping the data having publisher details
publisher=driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[5]")
for i in publisher:
    Publisher.append(i.text)
    
#Scrapping the data having genre details 
genre=driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[6]")
for i in genre:
    Genre.append(i.text)

# %%
#creating dataframe
df=pd.DataFrame({'Book-Name':Book,'Author':Author,'Volume-sales':Volume,'Publisher':Publisher,'Genre':Genre})
df
# Out:
#                                             Book-Name            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume-sales        Publisher                        Genre
# ...

# %% [markdown]
# # Q.9)

# %%
#Getting the website to driver
driver.get('https://www.imdb.com/list/ls095964455/')

# %%
#Creating empty lists for storing the scrapped data
Name=[]
Year=[]
Genre=[]
Runtime=[]
Rating=[]
Vote=[]

# %%
#Scrapping the data having the series name
name=driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']/a")
for i in name:
    Name.append(i.text)
    
#Scrapping the data having the year span details
year=driver.find_elements(By.XPATH,"//span[@class='lister-item-year text-muted unbold']")
for i in year:
    Year.append(i.text)
    
#Scrapping the data having the genre details
genre=driver.find_elements(By.XPATH,"//span[@class='genre']")
for i in genre:
    Genre.append(i.text)
    
#Scrapping the data having the runtime details
runtime=driver.find_elements(By.XPATH,"//span[@class='runtime']")
for i in runtime:
    Runtime.append(i.text)
    
#Scrapping the data having rating details
rating=driver.find_elements(By.XPATH,"//div[@class='ipl-rating-star small']")
for i in rating:
    Rating.append(i.text)
    
#Scrapping the data having the votes details
votes=driver.find_elements(By.XPATH,"//span[@name='nv']")
for i in votes:
    Vote.append(i.text)

# %%
#Creating a dataframe for the scrapped data
df=pd.DataFrame({'Name':Name,'Year span':Year,'Genre':Genre,'Runtime':Runtime,'Rating':Rating,'Votes':Vote})
df
# Out:
#                               Name    Year span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#     Runtime Rating      Votes
# 0    57 min    9.2  2,077,482
# ...

# %% [markdown]
# # Q.10)

# %%
#Getting the website to driver
driver.get('https://archive.ics.uci.edu/')

# %%
#Clicking on view all datasets link
datasets=driver.find_element(By.XPATH,"/html/body/table[1]/tbody/tr/td[2]/span[2]/a/font/b")
try:
    datasets.click()
except ElementNotInteractableException:
    driver.get(datasets.get_attribute('href'))

# %%
#Creating empty lists for storing the scrapped data
Name=[]
Type=[]
Task=[]
Attribute=[]
No_of_Instance=[]
No_of_Attribute=[]
Year=[]

# %%
#Scrapping the data having dataset name
try:
    names=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a")
    for i in names:
        Name.append(i.text)
except NoSuchElementException:
    Name.append('-')
    
#Scrapping the data having data type
try:
    types=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]")
    for i in types[1:]:
        Type.append(i.text)
except NoSuchElementException:
    Type.append('-')
    
#Scrapping the data having default task
try:
    task=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]")
    for i in task[1:]:
        Task.append(i.text)
except NoSuchElementException:
    Task.append('-')
        
#Scrapping the data having attribute types
try:
    attribute=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]")
    for i in attribute[1:]:
        Attribute.append(i.text)
except NoSuchElementException:
    Attribute.append('-')

#Scrapping the data having no of instances
try:
    instance=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]")
    for i in instance[1:]:
        No_of_Instance.append(i.text)
except NoSuchElementException:
    No_of_Instance.append('-')
        
#Scrapping the data having no of attributes
try:
    attribute_no=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]")
    for i in attribute_no[1:]:
        No_of_Attribute.append(i.text)
except NoSuchElementException:
    No_of_Attribute.append('-')
        
#Scrapping the data having the year details
try:
    year=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]")
    for i in year[1:]:
        Year.append(i.text)
except NoSuchElementException:
    Year.append('-')

# %%
#Creating the dataframe
df=pd.DataFrame({"Name":Name,"Data types":Type,"Default Task":Task,"Attribute types":Attribute, 
                 "No of instances":No_of_Instance,"No of atrributes":No_of_Attribute,"Year":Year})
df
# Out:
#                                                   Name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                      Data types          Default Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# ...
