# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time
import re

# %%
#connecting to the driver
driver=webdriver.Chrome(r"C:\python\chromedriver.exe")

# %% [markdown]
# # Q.1)

# %%
#opening the amazon page on automated chrome browser
driver.get("https://www.amazon.in/")

# %%
#entering user input
user_input= input('Enter the product name you want to search:')
# Out:
# Enter the product name you want to search:guitar

# %%
#search bar
bar=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
bar.send_keys(user_input)

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
search.click()

# %% [markdown]
# # Q.2)

# %%
productname=[]
start=0
end=3
for page in range(start,end):
    try:
        name=driver.find_elements(By.XPATH,"//span[@class='a-size-base-plus a-color-base a-text-normal']")
        for i in name:
            productname.append(i.text)
    except:
            productname.append('-')
    nxt_button = driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')                                         

    nxt_button.click()                                                   

    time.sleep(5)

# %%
print(productname)
# Out:
# ['Kadence Slowhand Premium Jumbo Semi Acoustic Guitar with Heavy Padded Bag, guitar cable, Pro Capo (Black Spruce Wood)', 'Blueberry 38C, 38" Acoustic Guitar Kit with Bag, Strap, One Pack Strings And Picks (Black)', "Hontral S4 String Decor Guitar Children's Musical Instrument Educational Toy Small Guitar for Beginners Kids Child - 23Inch", 'Festra 38C, 38 Inch Acoustic Guitar Kit with Bag, Strap, One Pack Strings And 2 Picks (Black)', 'Juârez Acoustic Guitar, 38 Inch Cutaway, 038C with Bag, Strings, Pick and Strap, Black', 'Intern INT-38C Right hand Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Black, small', 'Intern INT-38C-BK-G Cutaway Right Handed Acoustic Guitar Kit, with Bag, Nickel Strings, Pick And Strap (Black) -6 Strings', 'Yamaha F280 Acoustic Guitar, Natural', 'Kadence rosewood Guitar Frontier Series, Electric Acoustic Black Guitar With EQ, Die Cast Keys, Set Of Strings, Strap, Picks And Bag (Black EQ, Electric Acoustic)', 'Juarez Acoustic Guitar, 38 Inch Curved
# ...

# %%
len(productname)
# Out:
# 182

# %%
productprice=[]
start=0
end=3
for page in range(start,end):
    try:
        price=driver.find_elements(By.XPATH,"//span[@class='a-price-whole']")
        for i in price:
            productprice.append(i.text)
    except:
            productprice.append('-')
    nxt_button = driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')                                         

    nxt_button.click()                                                   

    time.sleep(5)

# %%
print(productprice)
# Out:
# ['9,999', '2,425', '899', '2,695', '2,399', '2,189', '7,490', '6,999', '1,979', '5,999', '2,589', '2,399', '2,229', '5,499', '3,109', '3,890', '10,575', '2,639', '2,399', '2,799', '9,100', '2,599', '6,999', '899', '2,655', '965', '2,695', '2,189', '7,990', '2,221', '7,752', '2,240', '3,549', '2,249', '7,600', '5,999', '9,500', '3,174', '3,260', '7,290', '3,146', '3,049', '3,420', '10,630', '13,200', '10,900', '3,061', '21,049', '7,658', '2,599', '2,639', '11,853', '4,538', '2,699', '2,278', '2,249', '5,856', '2,229', '6,999', '7,290', '2,695', '1,399', '6,499', '6,299', '5,499', '9,999', '6,299', '10,499', '4,495', '965', '2,515', '8,362', '3,246', '7,597', '29,679', '12,849', '2,941', '7,776', '7,727', '8,199', '6,099', '2,599', '3,599', '8,490', '5,504', '3,261', '17,899', '975', '2,895', '4,990', '6,400', '2,229', '25,889', '5,583', '2,699', '3,499', '2,250', '6,999', '5,348', '9,999', '12,101', '3,039', '2,278', '7,499', '7,780', '5,999', '43,626', '24,499', '2,639', '2,695', '1,
# ...

# %%
len(productprice)
# Out:
# 188

# %%
productrating=[]
start=0
end=3
for page in range(start,end):
    try:
        rating=driver.find_elements(By.XPATH,"//span[@class='a-size-base s-underline-text']")
        for i in rating:
            productrating.append(i.text)
    except:
            productrating.append('-')
    nxt_button = driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')                                         

    nxt_button.click()                                                   

    time.sleep(5)

# %%
print(productrating)
# Out:
# ['517', '20', '22', '17,668', '11,636', '2,181', '218', '1,484', '1,336', '2,379', '11,636', '2,195', '1,736', '3,640', '281', '421', '11,636', '11,636', '1,614', '331', '5,322', '1,298', '2', '141', '2', '2,195', '192', '285', '448', '532', '260', '2,195', '1,336', '2,494', '1,798', '1,338', '257', '384', '1,338', '7', '6', '103', '398', '421', '198', '168', '23', '5,589', '11,636', '537', '32', '216', '19', '1,484', '11', '1,484', '218', '384', '26', '37', '517', '22', '141', '2', '708', '168', '32', '30', '154', '448', '164', '175', '1,336', '33', '40', '39', '159', '355', '128', '161', '64', '13', '1,484', '47', '12', '86', '19', '2', '542', '53', '517', '1,063', '3,640', '6', '22', '694', '1', '2', '11,636', '2', '148', '20', '235', '1,059', '11', '33', '17', '76', '61', '733', '37', '2', '421', '22', '141', '15', '61', '733', '62', '1,267', '6', '1', '95', '2', '20', '250', '11', '4', '9', '384', '15', '90', '1,744', '1', '7', '195', '22', '557', '5', '20', '141', '104', '18', 
# ...

# %%
len(productrating)
# Out:
# 161

# %%
productdelivery=[]
start=0
end=3
for page in range(start,end):
    try:
        d=driver.find_elements(By.XPATH,"//span[@class='a-color-base a-text-bold']")
        for i in d:
            productdelivery.append(i.text)
    except:
            productdelivery.append('-')
    nxt_button = driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')                                         

    nxt_button.click()                                                   

    time.sleep(5)

# %%
print(productdelivery)
# Out:
# ['Sunday, October 30', 'Monday, October 31', 'Sunday, October 30', 'Monday, October 31', 'tomorrow, October 29', 'tomorrow, October 29', 'Sunday, October 30', 'Sunday, October 30', 'tomorrow, October 29', 'tomorrow, October 29', 'tomorrow, October 29', 'tomorrow, October 29', 'tomorrow, October 29', 'Sunday, October 30', 'tomorrow, October 29', 'tomorrow, October 29', 'tomorrow, October 29', 'tomorrow, October 29', 'Monday, October 31', 'tomorrow, October 29', 'Sunday, October 30', 'Sunday, October 30', 'Monday, October 31', 'Sunday, October 30', 'Monday, October 31', 'tomorrow, October 29', 'Monday, October 31', 'Wednesday, November 2', 'tomorrow, October 29', 'tomorrow, October 29', 'tomorrow, October 29', 'tomorrow, October 29', 'tomorrow, October 29', 'Sunday, October 30', 'Monday, October 31', 'Sunday, October 30', 'tomorrow, October 29', 'tomorrow, October 29', 'tomorrow, October 29', 'tomorrow, October 29', 'Sunday, October 30', 'tomorrow, October 29', 'Sunday, October 30', 'S
# ...

# %%
len(productdelivery)
# Out:
# 188

# %% [markdown]
# # Q.3)

# %%
#opening the google image on automated chrome browser
driver.get("https://images.google.com/")

# %%
#access the search bar
s=driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input")
s.send_keys('fruits')

# %%
#access the search button
search=driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button")
search.click()

# %%
#scraping 10images of fruits
fruits=[]
fruit=driver.find_elements(By.XPATH,"//img[@class='rg_i Q4LuWd']")
for i in fruit[0:10]:
    print(i.get_attribute('src'))
    fruits.append(i)
# Out:
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...

# %%
len(fruits)
# Out:
# 10

# %%
#scraping 10images of cakes
cakes=[]
cake=driver.find_elements(By.XPATH,"//img[@class='rg_i Q4LuWd']")
for i in cake[0:10]:
    print(i.get_attribute('src'))
    cakes.append(i)
# Out:
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...

# %%
#scraping 10images of guitars
guitars=[]
guitar=driver.find_elements(By.XPATH,"//img[@class='rg_i Q4LuWd']")
for i in guitar[0:10]:
    print(i.get_attribute('src'))
    guitars.append(i)
# Out:
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/png;base64,...
# data:image/jpeg;base64,...

# %%
#scraping 10images of cars
cars=[]
car=driver.find_elements(By.XPATH,"//img[@class='rg_i Q4LuWd']")
for i in car[0:10]:
    print(i.get_attribute('src'))
    cars.append(i)
# Out:
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...

# %%
#fetching 10images of machine learning
mls=[]
ml=driver.find_elements(By.XPATH,"//img[@class='rg_i Q4LuWd']")
for i in ml[0:10]:
    print(i.get_attribute('src'))
    mls.append(i)
# Out:
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/png;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...

# %% [markdown]
# # Q.4)

# %%
#opening the flipkart page on automated chrome browser
driver.get("https://www.flipkart.com/search?q=smartphone&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off")

# %%
#creating empty list
brandname=[]
Storage_RAM_ROM=[]
P_F_Camera=[]
Display_size_Resolution=[]
ProcessorAndCores=[]
battery=[]
price=[]

# %%
#scraping the brand name
name=driver.find_elements(By.XPATH,"//div[@class='_4rR01T']")
for i in name:
    if i.text is None :
        brandname.append("--") 
    else:
        brandname.append(i.text)

# %%
#scraping the Storage_RAM_ROM 
r=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[1]")
for i in r:
    if i.text is None :
        Storage_RAM_ROM.append("--") 
    else:
        Storage_RAM_ROM.append(i.text)

# %%
#scraping the P_F_Camera 
p=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[3]")
for i in p:
    if i.text is None :
        P_F_Camera.append("--") 
    else:
        P_F_Camera.append(i.text)

# %%
#scraping the Display_size_Resolution 
d=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[2]")
for i in d:
    if i.text is None :
        Display_size_Resolution.append("--") 
    else:
        Display_size_Resolution.append(i.text)

# %%
#scraping the ProcessorAndCores 
p=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[5]")
for i in p:
    if i.text is None :
        ProcessorAndCores.append("--") 
    else:
        ProcessorAndCores.append(i.text)

# %%
#scraping the Battery 
b=driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']//li[4]")
for i in b:
    if i.text is None :
        battery.append("--") 
    else:
        battery.append(i.text)

# %%
#scraping the Price 
prices=driver.find_elements(By.XPATH,"//div[@class='_30jeq3 _1_WHN1']")
for i in prices:
    if i.text is None :
        price.append("--") 
    else:
        price.append(i.text)

# %%
#creating dataframe
df=pd.DataFrame({'Brand-Name':brandname,'Storage-RAM-ROM':Storage_RAM_ROM,'Amount-PF-Camera':P_F_Camera,'Display-size-Resolution':Display_size_Resolution,'Processor&Cores':ProcessorAndCores,'Battery':battery,'Price':price})
df
# Out:
#                                       Brand-Name  \
# 0     SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)
# 1     SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)
# 2     SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)
# 3            REDMI 9i Sport (Coral Green, 64 GB)
# 4           REDMI 9i Sport (Carbon Black, 64 GB)
# 5      SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)
# 6   SAMSUNG Galaxy F23 5G (Forest Green, 128 GB)
# 7               I Kall K401PRO (SKY BLUE, 64 GB)
# 8                APPLE iPhone 11 (Black, 128 GB)
# 9                 APPLE iPhone 11 (Black, 64 GB)
# 10                  I Kall Z14 (Teernish, 64 GB)
# 11              I Kall Z2 PRO (Dark Blue, 16 GB)
# 12  SAMSUNG Galaxy F23 5G (Copper Blush, 128 GB)
# 13              APPLE iPhone 11 (Purple, 128 GB)
# 14                realme 9i (Prism Blue, 128 GB)
# 15               realme 9i (Prism Black, 128 GB)
# 16                  I Kall K525 (Tarnish, 64 GB)
# 17                     I Kall Z15 (Green, 64 GB)
# ...

# %%
#saving file to csv
df.to_csv('flipkart.csv')

# %% [markdown]
# # Q.5)

# %%
driver.get("https://www.google.com/maps/")

# %%
try:
    url_string = driver.current_url
    print("URL Extracted: ", url_string)
    lat_lng = re.findall(r'@(.*)data',url_string)
    if len(lat_lng):
        lat_lng_list = lat_lng[0].split(",")
        if len(lat_lng_list)>=2:
            lat = lat_lng_list[0]
            lng = lat_lng_list[1]
        print("Latitude = {}, Longitude = {}".format(lat, lng))

except Exception as e:
        print("Error: ", str(e))
# Out:
# URL Extracted:  https://www.google.com/maps/place/Mumbai,+Maharashtra/@19.0820391,72.600981,10z/data=!3m1!4b1!4m5!3m4!1s0x3be7c6306644edc1:0x5da4ed8f8d648c69!8m2!3d19.0759837!4d72.8776559
# Latitude = 19.0820391, Longitude = 72.600981

# %% [markdown]
# # Q.6)

# %%
#opening trak.in page
driver.get("https://www.trak.in")

# %%
#creating empty list
Dates=[]
Company=[]
Industry=[]
Investor_Name=[]
Investment_Type=[]
Amount=[]

# %%
#scraping the company_name 
companies=driver.find_elements(By.XPATH,"//td[@class='column-3']")
for i in companies:
    if i.text is None :
        Company.append("--") 
    else:
        Company.append(i.text)

# %%
#scraping the Industry 
Ind=driver.find_elements(By.XPATH,"//td[@class='column-4']")
for i in Ind:
    if i.text is None :
        Industry.append("--") 
    else:
        Industry.append(i.text)

# %%
#scraping the Dates 
dt=driver.find_elements(By.XPATH,"//td[@class='column-2']")
for i in dt:
    if i.text is None :
        Dates.append("--") 
    else:
        Dates.append(i.text)

# %%
#scraping the Investor_Name 
IN=driver.find_elements(By.XPATH,"//td[@class='column-7']")
for i in IN:
    if i.text is None :
        Investor_Name.append("--") 
    else:
        Investor_Name.append(i.text)

# %%
#scraping the Investment_Type 
IT=driver.find_elements(By.XPATH,"//td[@class='column-8']")
for i in IT:
    if i.text is None :
        Investment_Type.append("--") 
    else:
        Investment_Type.append(i.text)

# %%
#scraping the Amount 
Price=driver.find_elements(By.XPATH,"//td[@class='column-9']")
for i in Price:
    if i.text is None :
        Amount.append("--") 
    else:
        Amount.append(i.text)

# %%
#creating dataframe

df=pd.DataFrame({'comapny-name':Company,'industry':Industry,'investor-name':Investor_Name,'investment-type':Investment_Type,'amount':Amount,'date':Dates})
df[5:29]
# Out:
#               comapny-name                industry  \
# 5                DealShare              E-commerce
# 6                 Uniphore              Technology
# 7                    Dunzo              E-commerce
# 8                   BYJU’S                Edu-tech
# 9              SkilloVilla                Edu-tech
# 10                CityMall              E-commerce
# 11                   DotPe                 FinTech
# 12                Doubtnut                Edu Tech
# 13                  Zomato             Hospitality
# 14               Fingerlix             Hospitality
# 15                   Zolve                 FinTech
# 16               KreditBee                 Finance
# 17               Pepperfry              E-commerce
# 18                 Grofers              E-Commerce
# 19                 Nothing              Technology
# 20             SplashLearn                  EdTech
# 21         Digit Insurance      Financial Services
# ...

# %% [markdown]
# # Q.8)

# %%
#opening forbes.com page
driver.get("https://www.forbes.com")

# %%
#creating empty list
rank=[]
name=[]
networth=[]
age=[]
source=[]
industry=[]

# %%
#scraping data for rank

r=driver.find_elements(By.XPATH,"//div[@class='rank']")
for i in r:
    ra=i.text
    rank.append(ra)

# %%
#scraping data for name

n=driver.find_elements(By.XPATH,"//div[@class='personName']")
for i in n:
    na=i.text
    name.append(na)

# %%
#scraping data for net-worth

nwt=driver.find_elements(By.XPATH,"//div[@class='netWorth']")
for i in nwt:
    nw=i.text
    networth.append(nw)

# %%
#scraping data for country
citizenship=[]
c=driver.find_elements(By.XPATH,"//div[@class='countryOfCitizenship']")
for i in c:
    coun=i.text
    citizenship.append(coun)

# %%
#scraping data for source

s=driver.find_elements(By.XPATH,"//span[@class='source-text']")
for i in s:
    so=i.text
    source.append(so)

# %%
#scraping data for age

a=driver.find_elements(By.XPATH,"//div[@class='age']")
for i in a:
    ag=i.text
    age.append(ag)

# %%
#scraping data for industry

ind=driver.find_elements(By.XPATH,"//div[@class='category']")
for i in ind:
    indus=i.text
    industry.append(indus)

# %%
#creating dataframe

df=pd.DataFrame({'Rank':rank,'Name':name,'Age':age,'Citizenship':citizenship,'Net-Worth':networth,'Source':source,'Industry':industry})
df
# Out:
#      Rank                      Name Age    Citizenship Net-Worth  \
# 0      1.                 Elon Musk      United States    $219 B
# 1      2.                Jeff Bezos      United States    $171 B
# 2      3.  Bernard Arnault & family             France    $158 B
# 3      4.                Bill Gates      United States    $129 B
# 4      5.            Warren Buffett      United States    $118 B
# ..    ...                       ...  ..            ...       ...
# 195  192.    Marcel Herrmann Telles             Brazil   $10.3 B
# 196  197.                Leon Black      United States     $10 B
# 197  197.                Joe Gebbia      United States     $10 B
# 198  197.              David Geffen      United States     $10 B
# 199  197.                Yu Renrong              China     $10 B
#
#                     Source Industry
# 0            Tesla, SpaceX
# 1                   Amazon
# 2                     LVMH
# 3                Microsoft
# 4       Berkshire Hathaway
# ...

# %% [markdown]
# # Q.9)

# %%
#opening youtube page
driver.get("https://www.youtube.com")

# %%
name=[]
comment=[]
upvote=[]

# %%
#scraping data for name

n=driver.find_elements(By.XPATH,"//span[@class='style-scope ytd-comment-renderer']")
for i in n:
    if i.text is None:
        name.append('--')
    else:
        name.append(i.text)

# %%
#scraping time
comment_posted=[]
t=driver.find_elements(By.XPATH,"//a[@class='yt-simple-endpoint style-scope yt-formatted-string']")
for i in t:
    if i.text is None:
        comment_posted.append("--")
    else:
        comment_posted.append(i.text)

# %%
#scraping data for comment

cd=driver.find_elements(By.XPATH,"//yt-formatted-string[@class='style-scope ytd-comment-renderer']")
for i in cd:
    if i.text is None:
        comment.append("--")
    else:
        comment.append(i.text)

# %%
#scraping data for upvote

u=driver.find_elements(By.XPATH,"//span[@class='style-scope ytd-comment-action-buttons-renderer']")
for i in u:
    if i.text is None:
        upvote.append("--")
    else:
        upvote.append(i.text)

# %% [markdown]
# # Q.10)

# %%
#opening hostelworld page
driver.get("https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2022-10-28&to=2022-10-31&guests=2&page=1")

# %%
#scraping name of hostel
name=[]
n=driver.find_elements(By.XPATH,"//h2[@class='title title-6']")
for i in n:
    if i.text is None :
        name.append("--") 
    else:
        name.append(i.text)

# %%
#scraping distance of hostel
distance=[]
d=driver.find_elements(By.XPATH,"//span[@class='description']")
for i in d:
    if i.text is None :
        distance.append("--") 
    else:
        distance.append(i.text)

# %%
#scraping distance of hostel
distance=[]
d=driver.find_elements(By.XPATH,"//span[@class='description']")
for i in d:
    if i.text is None :
        distance.append("--") 
    else:
        distance.append(i.text)

# %%
#scraping rating of hostel
rating=[]
r=driver.find_elements(By.XPATH,"//div[@class='score orange big']")
for i in r:
    if i.text is None :
        rating.append("--") 
    else:
        rating.append(i.text)

# %%
#scraping total reviews of hostel
reviews=[]
re=driver.find_elements(By.XPATH,"//div[@class='reviews']")
for i in re:
    if i.text is None :
        reviews.append("--") 
    else:
        reviews.append(i.text)

# %%
#scraping overall reviews of hostel
overall=[]
o=driver.find_elements(By.XPATH,"//div[@class='keyword']")
for i in o:
    if i.text is None :
        overall.append("--") 
    else:
        overall.append(i.text)

# %%
#scraping dorms from price of hostel
dorm=[]
dp=driver.find_elements(By.XPATH,"//div[@class='price title-5']")
for i in dp:
    if i.text is None :
        dorm.append("--") 
    else:
        dorm.append(i.text)

# %%
#scraping private from price of hostel
dorm=[]
dp=driver.find_elements(By.XPATH,"//div[@class='price title-5']")
for i in dp:
    if i.text is None :
        dorm.append("--") 
    else:
        dorm.append(i.text)

# %%
#scraping facilities of hostel
facilities=[]
f=driver.find_elements(By.XPATH,"//div[@class='facilities-label facilities']")
for i in f:
    if i.text is None :
        facilities.append("--") 
    else:
        facilities.append(i.text)

# %% [markdown]
# # Q.7)

# %%
#opening the digit.in on automated chrome browser
driver.get("https://www.digit.in/")

# %%
names=[]
Products_Description=[]
Specification=[]
Price=[]

# %%
#scraping data for brand name

bn=driver.find_elements(By.XPATH,"//div[@class='left_side']")
for i in bn:
    b=i.text.split('\n')
    names.append(b)

# %%
print(names)
# Out:
# [['1.', 'MSI Titan GT77-12UHS'], ['2.', 'Alienware X17 R2'], ['3.', 'Acer Predator Triton 500 SE PT516-52s'], ['4.', 'Omen By HP (16-B1371TX)'], ['5.', 'Acer Predator Helios 300 AN515-45 (NH.QBRSI.0'], ['6.', 'MSI Delta 15 (A5EFK-083IN)'], ['7.', 'Omen By HP (16-C0141AX)'], ['8.', 'Lenovo Legion 5i Pro (82RF00MGIN)'], ['9.', 'Alienware M15 R5 Ryzen Edition Icc-C780001win'], ['10.', 'Lenovo Slim 7 Gen 6 (82K8002JIN)'], ['Digit.in is one of the most trusted and popular technology media portals in India. At Digit it is our goal to help Indian technology users decide what tech products they should buy. We do this by testing thousands of products in our two test labs in Noida and Mumbai, to arrive at indepth and unbiased buying advice for millions of Indians.']]

# %%
n=name[0:10]
n
# Out:
# [['1.', 'MSI Titan GT77-12UHS'],
#  ['2.', 'Alienware X17 R2'],
#  ['3.', 'Acer Predator Triton 500 SE PT516-52s'],
#  ['4.', 'Omen By HP (16-B1371TX)'],
#  ['5.', 'Acer Predator Helios 300 AN515-45 (NH.QBRSI.0'],
#  ['6.', 'MSI Delta 15 (A5EFK-083IN)'],
#  ['7.', 'Omen By HP (16-C0141AX)'],
#  ['8.', 'Lenovo Legion 5i Pro (82RF00MGIN)'],
#  ['9.', 'Alienware M15 R5 Ryzen Edition Icc-C780001win'],
#  ['10.', 'Lenovo Slim 7 Gen 6 (82K8002JIN)']]

# %%
#scraping data for price
p=driver.find_elements(By.XPATH,"//td[@class='smprice']")
for i in p:
    pr=i.text
    Price.append(pr)

# %%
print(Price)
# Out:
# ['N/A', '₹ 389,990', '₹ 300,000', '₹ 176,290', '₹ 172,999', '₹ 188,990', '₹ 124,990', '₹ 168,500', '₹ 144,990', '₹ 131,990']

# %%
#scraping data for specification
s=driver.find_elements(By.XPATH,"//div[@class='Specs-Wrap']")
for i in s:
    sf=i.text.split('\n')
    Specification.append(sf)

# %%
print(Specification)
# Out:
# [['Windows 11 Home OS', '17.3" (3840 x 2160) Display', '12th Gen Intel Core i9-12900HX | NA Processor', '2 TB SSD/64 GB DDR5 Memory'], ['Windows 11 Home OS', '17.3" (1920 x 1080) Display', '12th Gen Intel Core i9-12900H | 5 GHz Processor', '1 TB SSD/32 GB DDR5 Memory'], ['Windows 11 Home OS', '16" (2560 x 1600) Display', '12th Gen Intel Core i7-12700H | 3.50 GHz Processor', '2 TB SSD/32 GB DDR5 Memory'], ['Windows 11 Home OS', '16.1" (2560 x 1440) Display', '12th Gen Intel Core i7-12700H | 4.7 GHz Processor', '1 TB SSD/8 GB DDR5 Memory'], ['Windows 11 Home OS', '15.6" (2560 x 1440) Display', 'AMD Ryzen 9-5900HX | NA Processor', '512 GB SSD/16 GB DDR4 Memory'], ['Windows 11 Home OS', '15.6" (1920 x 1080) Display', 'AMD 5th Gen Ryzen 9-5900HX | 3.3GHz Processor', '1 TB SSD/16 GBGB DDR4 Memory'], ['Windows 11 Home OS', '16.1" (2560 x 1440) Display', 'AMD Ryzen™ 9 5900HX | 3.3 GHz Processor', '1 TB NVMe/16 GB DDR4 Memory'], ['Windows 11 Home OS', '16" (2560 x 1600) Display', '12th Gen In
# ...

# %%
#scraping data for product description
d=driver.find_elements(By.XPATH,"//div[@class='Specs-Wrap']")
for i in d:
    pd=i.text
    Products_Description.append(pd)

# %%
print(Products_Description)
# Out:
# ['Windows 11 Home OS\n17.3" (3840 x 2160) Display\n12th Gen Intel Core i9-12900HX | NA Processor\n2 TB SSD/64 GB DDR5 Memory', 'Windows 11 Home OS\n17.3" (1920 x 1080) Display\n12th Gen Intel Core i9-12900H | 5 GHz Processor\n1 TB SSD/32 GB DDR5 Memory', 'Windows 11 Home OS\n16" (2560 x 1600) Display\n12th Gen Intel Core i7-12700H | 3.50 GHz Processor\n2 TB SSD/32 GB DDR5 Memory', 'Windows 11 Home OS\n16.1" (2560 x 1440) Display\n12th Gen Intel Core i7-12700H | 4.7 GHz Processor\n1 TB SSD/8 GB DDR5 Memory', 'Windows 11 Home OS\n15.6" (2560 x 1440) Display\nAMD Ryzen 9-5900HX | NA Processor\n512 GB SSD/16 GB DDR4 Memory', 'Windows 11 Home OS\n15.6" (1920 x 1080) Display\nAMD 5th Gen Ryzen 9-5900HX | 3.3GHz Processor\n1 TB SSD/16 GBGB DDR4 Memory', 'Windows 11 Home OS\n16.1" (2560 x 1440) Display\nAMD Ryzen™ 9 5900HX | 3.3 GHz Processor\n1 TB NVMe/16 GB DDR4 Memory', 'Windows 11 Home OS\n16" (2560 x 1600) Display\n12th Gen Intel Core i7-12700H | 2.3 GHz Processor\n1 TB SSD/16 GB DDR5 M
# ...

# %%
#creating dataframe
import pandas as pd
df=pd.DataFrame({'Brands':n,'Prices':Price,'Product-Description':Products_Description,'Specifications':Specification})
df
# Out:
#                                               Brands     Prices  \
# 0                         [1., MSI Titan GT77-12UHS]        N/A
# 1                             [2., Alienware X17 R2]  ₹ 389,990
# 2        [3., Acer Predator Triton 500 SE PT516-52s]  ₹ 300,000
# 3                      [4., Omen By HP (16-B1371TX)]  ₹ 176,290
# 4  [5., Acer Predator Helios 300 AN515-45 (NH.QBR...  ₹ 172,999
# 5                   [6., MSI Delta 15 (A5EFK-083IN)]  ₹ 188,990
# 6                      [7., Omen By HP (16-C0141AX)]  ₹ 124,990
# 7            [8., Lenovo Legion 5i Pro (82RF00MGIN)]  ₹ 168,500
# 8  [9., Alienware M15 R5 Ryzen Edition Icc-C78000...  ₹ 144,990
# 9            [10., Lenovo Slim 7 Gen 6 (82K8002JIN)]  ₹ 131,990
#
#                                  Product-Description  \
# 0  Windows 11 Home OS\n17.3" (3840 x 2160) Displa...
# 1  Windows 11 Home OS\n17.3" (1920 x 1080) Displa...
# 2  Windows 11 Home OS\n16" (2560 x 1600) Display\...
# ...
